# %%
#1.student marks calculate average() 5 subjects. display pass or fail
def calculate_average(s1,s2,s3,s4,s5):
    average=(s1+s2+s3+s4+s5)/5
    return average
s1=int(input("Enter mark of subject1:"))
s2=int(input("Enter mark of subject2:"))
s3=int(input("Enter mark of subject3:"))
s4=int(input("Enter mark of subject4:"))
s5=int(input("Enter mark of subject5:"))
avg=calculate_average(s1,s2,s3,s4,s5)
print(f'average is :{avg}')
if avg>=40:
    print("'student passed")
else:
    print("student failed")
# Out:
# average is :44.8
# 'student passed

# %%
#2.create a function check_number() that accept a number even or odd test 5 numbers


def check_number(num):
     print('even') if num%2==0 else print('odd')
for i in range(5):
          num=int(input("enter a number"))
          check_number(num)
# Out:
# odd
# even
# odd
# even
# even

# %%
#3.create fun calculate_bill that accept quantity ofproduct calculate total amt give discount above 5000 return final amt.

def calculate_bill(price,quantity):
    total=price*quantity
    if total>5000:
        discound=total*10/100
        total=total-discound
        return total
price=int(input('Enter the price'))
quantity=int(input('Enter the quantity'))
final=calculate_bill(price,quantity)
print('final amount=',final)
# Out:
# final amount= 180000.0

# %%
#4.return the largest number without using built in max()

def find_largest(n1,n2,n3):
    return n1 if n1>n2 and n1>n3 else n2 if n2>n1 and n2>n3 else n3
find_largest(10,20,30)
# Out:
# 30
